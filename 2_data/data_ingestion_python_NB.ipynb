# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %%
database = 'datawarehouseanalytics_db'

engine = create_engine(f"mysql+mysqlconnector://root:1234@localhost/{database}")


folder = r"C:\Users\amarn\Project F1 my lap\DataWarehouseAnalytics\DataWareHouseAnalytics_CSV"

for file in os.listdir(folder):
    if file.endswith('.csv') and file.startswith('gold'):
        etc, table = file.replace('.csv', '').lower().split('.', 1)
        df = pd.read_csv(os.path.join(folder, file))
        df.to_sql(name = table, con = engine, if_exists='replace', index = False)
        print(f'{table} imported into {database}')
# Out:
# dim_customers imported into datawarehouseanalytics_db
# dim_products imported into datawarehouseanalytics_db
# fact_sales imported into datawarehouseanalytics_db
# report_customers imported into datawarehouseanalytics_db
# report_products imported into datawarehouseanalytics_db
